# %%
echo $MEM_LIMIT
# Out:
# 8196000000

# %%
ps aux
# Out:
# USER       PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# root         1  0.0  0.0 250224 11080 ?        Ss   Mar14   0:02 /usr/lib/system
# root         2  0.0  0.0      0     0 ?        S    Mar14   0:00 [kthreadd]
# root         3  0.0  0.0      0     0 ?        I<   Mar14   0:00 [rcu_gp]
# root         4  0.0  0.0      0     0 ?        I<   Mar14   0:00 [rcu_par_gp]
# root         6  0.0  0.0      0     0 ?        I<   Mar14   0:00 [kworker/0:0H-k
# root         8  0.0  0.0      0     0 ?        I<   Mar14   0:00 [mm_percpu_wq]
# root         9  0.0  0.0      0     0 ?        S    Mar14   0:00 [ksoftirqd/0]
# root        10  0.0  0.0      0     0 ?        I    Mar14   0:28 [rcu_sched]
# root        11  0.0  0.0      0     0 ?        S    Mar14   0:00 [migration/0]
# root        12  0.0  0.0      0     0 ?        S    Mar14   0:00 [watchdog/0]
# root        13  0.0  0.0      0     0 ?        S    Mar14   0:00 [cpuhp/0]
# ...
