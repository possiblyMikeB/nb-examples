# %%
# !wget https://i.imgur.com/ZTbC1o5.jpg
# Out:
# --2020-04-10 22:21:34--  https://i.imgur.com/ZTbC1o5.jpg
# Resolving i.imgur.com (i.imgur.com)... 199.232.36.193
# Connecting to i.imgur.com (i.imgur.com)|199.232.36.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 869544 (849K) [image/jpeg]
# Saving to: ‘ZTbC1o5.jpg’
#
# ZTbC1o5.jpg         100%[===================>] 849.16K  --.-KB/s    in 0.09s
#
# 2020-04-10 22:21:34 (9.55 MB/s) - ‘ZTbC1o5.jpg’ saved [869544/869544]

# %%
from PIL import Image
Image.open('./ZTbC1o5.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1536x2048 at 0x15175E5A6390>
